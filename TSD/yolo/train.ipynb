# %%
#! /usr/bin/env python

import argparse
import os
import numpy as np
import json
from yolo import create_model, dummy_loss
from generator import BatchGenerator
from utils.utils import normalize, evaluate, makedirs, init_session
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras.optimizers import Adam
from keras.utils.layer_utils import print_summary

import keras
from keras.models import load_model
from _common import utils
from _common.callbacks import CustomModelCheckpoint, CustomTensorBoard, MAP_evaluation
from _common.voc import parse_voc_annotation, split_by_objects, replace_all_labels_2_one

def create_training_instances(
        train_annot_folder,
        train_image_folder,
        train_cache,
        valid_annot_folder,
        valid_image_folder,
        valid_cache,
        labels,
):
    # parse annotations of the training set
    train_ints, train_labels = parse_voc_annotation(train_annot_folder, train_image_folder, train_cache, labels)

    # parse annotations of the validation set, if any, otherwise split the training set
    if valid_annot_folder:
        valid_ints, valid_labels = parse_voc_annotation(valid_annot_folder, valid_image_folder, valid_cache, labels)
    else:
        print("valid_annot_folder not exists. Spliting the trainining set.")

        train_ints, valid_ints = split_by_objects(train_ints, train_labels, 0.2)

    # Hack - replace full dataset to only one class
    train_ints, train_labels = replace_all_labels_2_one( train_ints, 'sign' )
    valid_ints, valid_labels = replace_all_labels_2_one( valid_ints, 'sign' )
        
        
    # compare the seen labels with the given labels in config.json
    if len(labels) > 0:
        overlap_labels = set(labels).intersection(set(train_labels.keys()))

        print('Seen labels: \t' + str(train_labels) + '\n')
        print('Given labels: \t' + str(labels))

        # return None, None, None if some given label is not in the dataset
        if len(overlap_labels) < len(labels):
            print('Some labels have no annotations! Please revise the list of labels in the config.json.')
            return None, None, None
    else:
        print('No labels are provided. Train on all seen labels.')
        print(train_labels)
        print(valid_labels)
        labels = train_labels.keys()

    max_box_per_image = max([len(inst['object']) for inst in (train_ints + valid_ints)])

    return train_ints, valid_ints, sorted(labels), max_box_per_image


def train(config, initial_weights):

    init_session(1.0)

    if config['train']['cache_name']:
        makedirs(os.path.dirname(config['train']['cache_name']))

    ###############################
    #   Parse the annotations
    ###############################
    train_ints, valid_ints, labels, max_box_per_image = create_training_instances(
        config['train']['train_annot_folder'],
        config['train']['train_image_folder'],
        config['train']['cache_name'],
        config['valid']['valid_annot_folder'],
        config['valid']['valid_image_folder'],
        config['valid']['cache_name'],
        config['model']['labels']
    )
    print('\nTraining on: \t' + str(labels) + '\n')

    ###############################
    #   Create the generators
    ###############################
    train_generator = BatchGenerator(
        instances=train_ints,
        anchors=config['model']['anchors'],
        labels=labels,
        downsample=32,  # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image=max_box_per_image,
        batch_size=config['train']['batch_size'],
        min_net_size=config['model']['min_input_size'],
        max_net_size=config['model']['max_input_size'],
        shuffle=True,
        jitter=0.1,
        norm=normalize
    )

    valid_generator = BatchGenerator(
        instances=valid_ints,
        anchors=config['model']['anchors'],
        labels=labels,
        downsample=32,  # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image=max_box_per_image,
        batch_size=config['train']['batch_size'],
        norm=normalize,
        infer_sz=config['model']['infer_shape']
    )

    ###############################
    #   Create the model
    ###############################

    os.environ['CUDA_VISIBLE_DEVICES'] = config['train']['gpus']
    multi_gpu = len(config['train']['gpus'].split(','))

    freezing = True
    config['train']['warmup_epochs'] = 0

    warmup_batches = config['train']['warmup_epochs'] * (config['train']['train_times'] * len(train_generator))

    train_model, infer_model, _, freeze_num = create_model(
        nb_class=len(labels),
        anchors=config['model']['anchors'],
        max_box_per_image=max_box_per_image,
        max_input_size=config['model']['max_input_size'],
        batch_size=config['train']['batch_size'],
        warmup_batches=warmup_batches,
        ignore_thresh=config['train']['ignore_thresh'],
        multi_gpu=multi_gpu,
        grid_scales=config['train']['grid_scales'],
        obj_scale=config['train']['obj_scale'],
        noobj_scale=config['train']['noobj_scale'],
        xywh_scale=config['train']['xywh_scale'],
        class_scale=config['train']['class_scale'],
        base=config['model']['base']
    )

    from keras.utils.vis_utils import plot_model
    model_render_file = 'images/{}.png'.format(config['model']['base'])
    if not os.path.isdir(os.path.dirname(model_render_file)):
        os.makedirs(os.path.dirname(model_render_file))
    plot_model(infer_model, to_file=model_render_file, show_shapes=True)
#     print_summary(infer_model)

    # load the pretrained weight if exists, otherwise load the backend weight only
    if initial_weights and os.path.exists(initial_weights):
        print("\nLoading pretrained weights {}".format(initial_weights))
        train_model.load_weights(initial_weights, by_name=True, skip_mismatch=True)

        freezing = False

    ###############################
    #   Kick off the training
    ###############################
    tensorboard_logdir = utils.get_tensorboard_name(config)
    checkpoint_name = utils.get_checkpoint_name(config)
    mAP_checkpoint_name = utils.get_mAP_checkpoint_name(config)
    utils.makedirs(tensorboard_logdir)
    utils.makedirs_4_file(checkpoint_name)
    utils.makedirs_4_file(mAP_checkpoint_name)

    print('Tensorboard dir: {}'.format(tensorboard_logdir))


    early_stop = EarlyStopping(
        monitor='val_loss',
        min_delta=0.1,
        patience=3,
        mode='min',
        verbose=1
    )

    callbacks = [early_stop]

    if freezing and freeze_num > 0:
        print('Freezing %d layers of %d' % (freeze_num, len(infer_model.layers)))
        for l in range(freeze_num):
            infer_model.layers[l].trainable = False

        # optimizer = Adam(lr=1e-3, clipnorm=0.1)
        optimizer = Adam()
        train_model.compile(loss=dummy_loss, optimizer=optimizer)
        train_model.fit_generator(
            generator=train_generator,
            steps_per_epoch=len(train_generator) * config['train']['train_times'],

            validation_data=valid_generator,
            validation_steps=len(valid_generator) * config['valid']['valid_times'],

            epochs=config['train']['nb_epochs'] + config['train']['warmup_epochs'],
            verbose=2 if config['train']['debug'] else 1,
            callbacks=callbacks,
            workers=8,
            max_queue_size=100
        )

    # make a GPU version of infer_model for evaluation
    # if multi_gpu > 1:
    #     infer_model = load_model(config['train']['saved_weights_name'])

    print('Full training')

    for layer in infer_model.layers:
        layer.trainable = True

    checkpoint_vloss = CustomModelCheckpoint(
        model_to_save=infer_model,
        filepath=checkpoint_name,
        monitor='val_loss',
        verbose=1,
        save_best_only=True,
        mode='min',
        period=1
    )

    reduce_on_plateau = ReduceLROnPlateau(
        monitor='loss',
        factor=0.5,
        patience=5,
        verbose=1,
        mode='min',
        min_delta=0.01,
        cooldown=0,
        min_lr=0
    )

    tensorboard_cb = TensorBoard(log_dir=tensorboard_logdir,
                                 histogram_freq=0,
                                 write_graph=True,
                                 write_images=False)

    map_evaluator_cb = MAP_evaluation(infer_model=infer_model,
                                      generator=valid_generator,
                                      save_best=True,
                                      save_name=mAP_checkpoint_name,
                                      tensorboard=tensorboard_cb,
                                      iou_threshold=0.5,
                                      score_threshold=0.5,
                                      infer_sz=config['model']['infer_shape'],
                                      evaluate=evaluate)

    early_stop = EarlyStopping(
        monitor='val_loss',
        min_delta=0,
        patience=20,
        mode='min',
        verbose=1
    )

    from keras.optimizers import SGD

    callbacks = [checkpoint_vloss, tensorboard_cb, map_evaluator_cb]

    optimizer = Adam(lr=config['train']['learning_rate'], clipnorm=0.001)
    # optimizer = SGD(lr=config['train']['learning_rate'], clipnorm=0.001)

    train_model.compile(loss=dummy_loss, optimizer=optimizer)
    train_model.fit_generator(
        generator=train_generator,
        steps_per_epoch=len(train_generator) * config['train']['train_times'],

        validation_data=valid_generator,
        validation_steps=len(valid_generator) * config['valid']['valid_times'],

        epochs=config['train']['nb_epochs'] + config['train']['warmup_epochs'],
        verbose=2 if config['train']['debug'] else 1,
        callbacks=callbacks,
        workers=8,
        max_queue_size=100
    )

    ###############################
    #   Run the evaluation
    ###############################
    # compute mAP for all the classes
    average_precisions = evaluate(model=infer_model,
                                  generator=valid_generator,
                                  iou_threshold=0.5,
                                  net_h=config['model']['infer_shape'][0],
                                  net_w=config['model']['infer_shape'][1] )

    # print the score
    for label, average_precision in average_precisions.items():
        print(labels[label] + ': {:.4f}'.format(average_precision))
    print('Last mAP: {:.4f}'.format(sum(average_precisions.values()) / len(average_precisions)))


if __name__ == '__main__':
    config_path = 'cfgs/signs_tiny_v3.json'
    initial_weights = None

    with open(config_path) as config_buffer:
        config = json.loads(config_buffer.read())

    train(config, initial_weights)
# Out:
# Using TensorFlow backend.
# No labels are provided. Train on all seen labels.
# {'sign': 852}
# {'sign': 476}
#
# Training on: 	['sign']
#
# Loading "TinyV3" model
# YoloLayer anchors: [14, 24, 20, 33, 31, 51] / max_grid: [14, 14]
# YoloLayer anchors: [6, 11, 8, 14, 11, 18] / max_grid: [28, 28]
# Laoding yolov3-tiny.h5
# /home/alex/nn_venv/lib/python3.5/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_10 due to mismatch in shape ((1, 1, 512, 18) vs (255, 512, 1, 1)).
#   weight_values[i].shape))
# /home/alex/nn_venv/lib/python3.5/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_10 due to mismatch in shape ((18,) vs (255,)).
#   weight_values[i].shape))
# /home/alex/nn_venv/lib/python3.5/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_13 due to mismatch in shape ((1, 1, 256, 18) vs (255, 256, 1, 1)).
#   weight_values[i].shape))
# /home/alex/nn_venv/lib/python3.5/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_13 due to mismatch in shape ((18,) vs (255,)).
#   weight_values[i].shape))
# Tensorboard dir: logs/TSD_YOLOv3_Tiny_TinyV3_416x416-1
# Freezing 40 layers of 44
# Epoch 1/1000
# 750/750 [==============================] - 30s 39ms/step - loss: 28.3739 - yolo_layer_1_loss: 5.9133 - yolo_layer_2_loss: 18.3413 - val_loss: 28.4190 - val_yolo_layer_1_loss: 8.3399 - val_yolo_layer_2_loss: 15.9616
# Epoch 2/1000
# 750/750 [==============================] - 24s 32ms/step - loss: 21.3332 - yolo_layer_1_loss: 4.5876 - yolo_layer_2_loss: 12.6290 - val_loss: 27.8030 - val_yolo_layer_1_loss: 9.0449 - val_yolo_layer_2_loss: 14.6420
# Epoch 3/1000
# 750/750 [==============================] - 25s 33ms/step - loss: 19.2595 - yolo_layer_1_loss: 4.3584 - yolo_layer_2_loss: 10.7854 - val_loss: 26.1351 - val_yolo_layer_1_loss: 7.8535 - val_yolo_layer_2_loss: 14.1661
# Epoch 4/1000
# 750/750 [==============================] - 23s 31ms/step - loss: 18.2311 - yolo_layer_1_loss: 4.0001 - yolo_layer_2_loss: 10.1156 - val_loss: 25.4669 - val_yolo_layer_1_loss: 7.8653 - val_yolo_layer_2_loss: 13.4862
# Epoch 5/1000
# 750/750 [==============================] - 24s 32ms/step - loss: 18.3660 - yolo_layer_1_loss: 4.4921 - yolo_layer_2_loss: 9.7585 - val_loss: 25.5318 - val_yolo_layer_1_loss: 8.0425 - val_yolo_layer_2_loss: 13.3740
# Epoch 6/1000
# 750/750 [==============================] - 24s 33ms/step - loss: 18.1084 - yolo_layer_1_loss: 4.2963 - yolo_layer_2_loss: 9.6966 - val_loss: 25.0177 - val_yolo_layer_1_loss: 7.5917 - val_yolo_layer_2_loss: 13.3105
# Epoch 7/1000
# 750/750 [==============================] - 24s 32ms/step - loss: 18.0389 - yolo_layer_1_loss: 4.2493 - yolo_layer_2_loss: 9.6741 - val_loss: 24.5916 - val_yolo_layer_1_loss: 7.4309 - val_yolo_layer_2_loss: 13.0452
# Epoch 8/1000
# 750/750 [==============================] - 23s 31ms/step - loss: 17.7597 - yolo_layer_1_loss: 3.9175 - yolo_layer_2_loss: 9.7267 - val_loss: 24.5964 - val_yolo_layer_1_loss: 7.3113 - val_yolo_layer_2_loss: 13.1696
# Epoch 9/1000
# 750/750 [==============================] - 25s 34ms/step - loss: 18.0677 - yolo_layer_1_loss: 4.3733 - yolo_layer_2_loss: 9.5783 - val_loss: 24.7939 - val_yolo_layer_1_loss: 7.4706 - val_yolo_layer_2_loss: 13.2059
# Epoch 10/1000
# 750/750 [==============================] - 25s 33ms/step - loss: 17.8685 - yolo_layer_1_loss: 3.9982 - yolo_layer_2_loss: 9.7522 - val_loss: 24.5768 - val_yolo_layer_1_loss: 7.2182 - val_yolo_layer_2_loss: 13.2402
# Epoch 00010: early stopping
# Full training
# Epoch 1/1000
# 750/750 [==============================] - 55s 73ms/step - loss: 16.3661 - yolo_layer_1_loss: 3.6108 - yolo_layer_2_loss: 8.6414 - val_loss: 24.0616 - val_yolo_layer_1_loss: 6.9893 - val_yolo_layer_2_loss: 12.9647
#
# Epoch 00001: val_loss improved from inf to 24.06162, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep001-val_loss24.062-loss16.366.h5
#
#
# 0 0.0001
# mAP: 0.0001
#
# Epoch 00000: mAP improved from 8.02506e-05 to 8.02506e-05, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep001-val_loss24.062-best_mAP0.000.h5
# Epoch 2/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 14.7344 - yolo_layer_1_loss: 2.9671 - yolo_layer_2_loss: 7.6679 - val_loss: 24.0830 - val_yolo_layer_1_loss: 6.9567 - val_yolo_layer_2_loss: 13.0360
#
# Epoch 00002: val_loss did not improve from 24.06162
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 3/1000
# 750/750 [==============================] - 47s 62ms/step - loss: 13.6318 - yolo_layer_1_loss: 2.6955 - yolo_layer_2_loss: 6.8562 - val_loss: 24.7715 - val_yolo_layer_1_loss: 7.3789 - val_yolo_layer_2_loss: 13.3230
#
# Epoch 00003: val_loss did not improve from 24.06162
#
#
# 0 0.0007
# mAP: 0.0007
# mAP did not improve from 8.02506495960348e-05.
# Epoch 4/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 12.7437 - yolo_layer_1_loss: 2.1459 - yolo_layer_2_loss: 6.5392 - val_loss: 24.3485 - val_yolo_layer_1_loss: 6.9491 - val_yolo_layer_2_loss: 13.3519
#
# Epoch 00004: val_loss did not improve from 24.06162
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 5/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 12.0062 - yolo_layer_1_loss: 1.9429 - yolo_layer_2_loss: 6.0267 - val_loss: 24.3198 - val_yolo_layer_1_loss: 6.9249 - val_yolo_layer_2_loss: 13.3692
#
# Epoch 00005: val_loss did not improve from 24.06162
#
#
# 0 0.0013
# mAP: 0.0013
# mAP did not improve from 8.02506495960348e-05.
# Epoch 6/1000
# 750/750 [==============================] - 45s 61ms/step - loss: 11.5888 - yolo_layer_1_loss: 1.9177 - yolo_layer_2_loss: 5.6560 - val_loss: 24.2799 - val_yolo_layer_1_loss: 6.9120 - val_yolo_layer_2_loss: 13.3635
#
# Epoch 00006: val_loss did not improve from 24.06162
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 7/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 11.1866 - yolo_layer_1_loss: 1.6657 - yolo_layer_2_loss: 5.5265 - val_loss: 24.5345 - val_yolo_layer_1_loss: 7.2637 - val_yolo_layer_2_loss: 13.2865
#
# Epoch 00007: val_loss did not improve from 24.06162
#
#
# 0 0.0010
# mAP: 0.0010
# mAP did not improve from 8.02506495960348e-05.
# Epoch 8/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 10.9842 - yolo_layer_1_loss: 1.4332 - yolo_layer_2_loss: 5.5775 - val_loss: 24.5251 - val_yolo_layer_1_loss: 7.1225 - val_yolo_layer_2_loss: 13.4400
#
# Epoch 00008: val_loss did not improve from 24.06162
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 8.02506495960348e-05.
# Epoch 9/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 10.6866 - yolo_layer_1_loss: 1.6451 - yolo_layer_2_loss: 5.0893 - val_loss: 24.3886 - val_yolo_layer_1_loss: 6.9734 - val_yolo_layer_2_loss: 13.4734
#
# Epoch 00009: val_loss did not improve from 24.06162
#
#
# 0 0.0014
# mAP: 0.0014
# mAP did not improve from 8.02506495960348e-05.
# Epoch 10/1000
# 750/750 [==============================] - 47s 62ms/step - loss: 10.4097 - yolo_layer_1_loss: 1.6264 - yolo_layer_2_loss: 4.8519 - val_loss: 24.3833 - val_yolo_layer_1_loss: 7.0320 - val_yolo_layer_2_loss: 13.4307
#
# Epoch 00010: val_loss did not improve from 24.06162
#
#
# 0 0.0003
# mAP: 0.0003
# mAP did not improve from 8.02506495960348e-05.
# Epoch 11/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 10.1698 - yolo_layer_1_loss: 1.2698 - yolo_layer_2_loss: 4.9904 - val_loss: 24.5673 - val_yolo_layer_1_loss: 7.0392 - val_yolo_layer_2_loss: 13.6291
#
# Epoch 00011: val_loss did not improve from 24.06162
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 8.02506495960348e-05.
# Epoch 12/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 9.9130 - yolo_layer_1_loss: 1.4073 - yolo_layer_2_loss: 4.6170 - val_loss: 24.3163 - val_yolo_layer_1_loss: 6.9061 - val_yolo_layer_2_loss: 13.5318
#
# Epoch 00012: val_loss did not improve from 24.06162
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 8.02506495960348e-05.
# Epoch 13/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 9.6785 - yolo_layer_1_loss: 1.1851 - yolo_layer_2_loss: 4.6258 - val_loss: 24.1132 - val_yolo_layer_1_loss: 6.7102 - val_yolo_layer_2_loss: 13.5462
#
# Epoch 00013: val_loss did not improve from 24.06162
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 8.02506495960348e-05.
# Epoch 14/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 9.5522 - yolo_layer_1_loss: 1.3051 - yolo_layer_2_loss: 4.4005 - val_loss: 24.1829 - val_yolo_layer_1_loss: 6.7796 - val_yolo_layer_2_loss: 13.5670
#
# Epoch 00014: val_loss did not improve from 24.06162
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 8.02506495960348e-05.
# Epoch 15/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 9.5016 - yolo_layer_1_loss: 1.2762 - yolo_layer_2_loss: 4.3995 - val_loss: 24.5721 - val_yolo_layer_1_loss: 7.1113 - val_yolo_layer_2_loss: 13.6452
#
# Epoch 00015: val_loss did not improve from 24.06162
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 16/1000
# 750/750 [==============================] - 45s 61ms/step - loss: 9.4410 - yolo_layer_1_loss: 1.2798 - yolo_layer_2_loss: 4.3558 - val_loss: 23.8860 - val_yolo_layer_1_loss: 6.5670 - val_yolo_layer_2_loss: 13.5236
#
# Epoch 00016: val_loss improved from 24.06162 to 23.88600, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep016-val_loss23.886-loss9.441.h5
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 8.02506495960348e-05.
# Epoch 17/1000
# 750/750 [==============================] - 44s 58ms/step - loss: 9.3435 - yolo_layer_1_loss: 1.0679 - yolo_layer_2_loss: 4.4903 - val_loss: 24.4734 - val_yolo_layer_1_loss: 6.9617 - val_yolo_layer_2_loss: 13.7366
#
# Epoch 00017: val_loss did not improve from 23.88600
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 8.02506495960348e-05.
# Epoch 18/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 9.0828 - yolo_layer_1_loss: 1.1194 - yolo_layer_2_loss: 4.1989 - val_loss: 24.4116 - val_yolo_layer_1_loss: 6.9025 - val_yolo_layer_2_loss: 13.7551
#
# Epoch 00018: val_loss did not improve from 23.88600
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 19/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 9.0434 - yolo_layer_1_loss: 1.1112 - yolo_layer_2_loss: 4.1884 - val_loss: 24.2779 - val_yolo_layer_1_loss: 6.7481 - val_yolo_layer_2_loss: 13.7962
#
# Epoch 00019: val_loss did not improve from 23.88600
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 20/1000
# 750/750 [==============================] - 47s 63ms/step - loss: 8.8605 - yolo_layer_1_loss: 1.1936 - yolo_layer_2_loss: 3.9432 - val_loss: 24.4051 - val_yolo_layer_1_loss: 6.8634 - val_yolo_layer_2_loss: 13.8282
#
# Epoch 00020: val_loss did not improve from 23.88600
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 21/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 8.7913 - yolo_layer_1_loss: 1.1788 - yolo_layer_2_loss: 3.9089 - val_loss: 24.4889 - val_yolo_layer_1_loss: 6.9671 - val_yolo_layer_2_loss: 13.8286
#
# Epoch 00021: val_loss did not improve from 23.88600
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 22/1000
# 750/750 [==============================] - 44s 58ms/step - loss: 8.8116 - yolo_layer_1_loss: 1.0078 - yolo_layer_2_loss: 4.1210 - val_loss: 24.1219 - val_yolo_layer_1_loss: 6.7508 - val_yolo_layer_2_loss: 13.6986
#
# Epoch 00022: val_loss did not improve from 23.88600
#
#
# 0 0.0002
# mAP: 0.0002
# mAP did not improve from 8.02506495960348e-05.
# Epoch 23/1000
# 750/750 [==============================] - 44s 58ms/step - loss: 8.5979 - yolo_layer_1_loss: 1.0227 - yolo_layer_2_loss: 3.9133 - val_loss: 24.0613 - val_yolo_layer_1_loss: 6.7587 - val_yolo_layer_2_loss: 13.6514
#
# Epoch 00023: val_loss did not improve from 23.88600
#
#
# 0 0.0003
# mAP: 0.0003
#
# Epoch 00022: mAP improved from 0.000347947 to 0.000347947, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep023-val_loss24.061-best_mAP0.000.h5
# Epoch 24/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 8.4798 - yolo_layer_1_loss: 0.9710 - yolo_layer_2_loss: 3.8674 - val_loss: 24.5893 - val_yolo_layer_1_loss: 7.0543 - val_yolo_layer_2_loss: 13.9034
#
# Epoch 00024: val_loss did not improve from 23.88600
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 25/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 8.4988 - yolo_layer_1_loss: 0.9848 - yolo_layer_2_loss: 3.8921 - val_loss: 24.3246 - val_yolo_layer_1_loss: 6.8859 - val_yolo_layer_2_loss: 13.8267
#
# Epoch 00025: val_loss did not improve from 23.88600
#
#
# 0 0.0003
# mAP: 0.0003
# mAP did not improve from 0.00034794711203897004.
# Epoch 26/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 8.3165 - yolo_layer_1_loss: 0.9017 - yolo_layer_2_loss: 3.8130 - val_loss: 24.0767 - val_yolo_layer_1_loss: 6.6600 - val_yolo_layer_2_loss: 13.8251
#
# Epoch 00026: val_loss did not improve from 23.88600
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 27/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 8.2386 - yolo_layer_1_loss: 0.9234 - yolo_layer_2_loss: 3.7335 - val_loss: 24.1216 - val_yolo_layer_1_loss: 6.7340 - val_yolo_layer_2_loss: 13.8153
#
# Epoch 00027: val_loss did not improve from 23.88600
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 28/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 8.2584 - yolo_layer_1_loss: 0.9382 - yolo_layer_2_loss: 3.7577 - val_loss: 24.1742 - val_yolo_layer_1_loss: 6.7760 - val_yolo_layer_2_loss: 13.8454
#
# Epoch 00028: val_loss did not improve from 23.88600
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 29/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 8.2275 - yolo_layer_1_loss: 1.0014 - yolo_layer_2_loss: 3.6831 - val_loss: 24.0972 - val_yolo_layer_1_loss: 6.7394 - val_yolo_layer_2_loss: 13.8243
#
# Epoch 00029: val_loss did not improve from 23.88600
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 30/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 8.0951 - yolo_layer_1_loss: 1.0238 - yolo_layer_2_loss: 3.5473 - val_loss: 24.4601 - val_yolo_layer_1_loss: 6.9425 - val_yolo_layer_2_loss: 14.0034
#
# Epoch 00030: val_loss did not improve from 23.88600
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 31/1000
# 750/750 [==============================] - 45s 59ms/step - loss: 8.0294 - yolo_layer_1_loss: 0.9955 - yolo_layer_2_loss: 3.5293 - val_loss: 24.0442 - val_yolo_layer_1_loss: 6.8642 - val_yolo_layer_2_loss: 13.6851
#
# Epoch 00031: val_loss did not improve from 23.88600
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 32/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 7.9577 - yolo_layer_1_loss: 0.9574 - yolo_layer_2_loss: 3.5150 - val_loss: 24.4445 - val_yolo_layer_1_loss: 7.0717 - val_yolo_layer_2_loss: 13.8971
#
# Epoch 00032: val_loss did not improve from 23.88600
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 33/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 7.8427 - yolo_layer_1_loss: 0.8359 - yolo_layer_2_loss: 3.5407 - val_loss: 24.0892 - val_yolo_layer_1_loss: 6.9166 - val_yolo_layer_2_loss: 13.7162
#
# Epoch 00033: val_loss did not improve from 23.88600
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 34/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 7.7299 - yolo_layer_1_loss: 0.8748 - yolo_layer_2_loss: 3.4081 - val_loss: 23.7432 - val_yolo_layer_1_loss: 6.6197 - val_yolo_layer_2_loss: 13.6859
#
# Epoch 00034: val_loss improved from 23.88600 to 23.74324, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep034-val_loss23.743-loss7.730.h5
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 35/1000
# 750/750 [==============================] - 44s 58ms/step - loss: 7.8168 - yolo_layer_1_loss: 0.8218 - yolo_layer_2_loss: 3.5673 - val_loss: 23.8031 - val_yolo_layer_1_loss: 6.6269 - val_yolo_layer_2_loss: 13.7583
#
# Epoch 00035: val_loss did not improve from 23.74324
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 36/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 7.8379 - yolo_layer_1_loss: 1.0199 - yolo_layer_2_loss: 3.4092 - val_loss: 23.9481 - val_yolo_layer_1_loss: 6.6963 - val_yolo_layer_2_loss: 13.8523
#
# Epoch 00036: val_loss did not improve from 23.74324
#
#
# 0 0.0003
# mAP: 0.0003
# mAP did not improve from 0.00034794711203897004.
# Epoch 37/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 7.6939 - yolo_layer_1_loss: 0.8654 - yolo_layer_2_loss: 3.4384 - val_loss: 23.8397 - val_yolo_layer_1_loss: 6.7472 - val_yolo_layer_2_loss: 13.7119
#
# Epoch 00037: val_loss did not improve from 23.74324
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 38/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 7.5161 - yolo_layer_1_loss: 0.8621 - yolo_layer_2_loss: 3.2828 - val_loss: 23.5458 - val_yolo_layer_1_loss: 6.4411 - val_yolo_layer_2_loss: 13.7428
#
# Epoch 00038: val_loss improved from 23.74324 to 23.54578, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep038-val_loss23.546-loss7.516.h5
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 39/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 7.5336 - yolo_layer_1_loss: 0.7795 - yolo_layer_2_loss: 3.4013 - val_loss: 23.7660 - val_yolo_layer_1_loss: 6.6579 - val_yolo_layer_2_loss: 13.7645
#
# Epoch 00039: val_loss did not improve from 23.54578
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 40/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 7.4546 - yolo_layer_1_loss: 0.7834 - yolo_layer_2_loss: 3.3371 - val_loss: 23.9237 - val_yolo_layer_1_loss: 6.7348 - val_yolo_layer_2_loss: 13.8643
#
# Epoch 00040: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 41/1000
# 750/750 [==============================] - 45s 61ms/step - loss: 7.5639 - yolo_layer_1_loss: 0.8650 - yolo_layer_2_loss: 3.3834 - val_loss: 23.8451 - val_yolo_layer_1_loss: 6.7781 - val_yolo_layer_2_loss: 13.7605
#
# Epoch 00041: val_loss did not improve from 23.54578
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 42/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 7.3850 - yolo_layer_1_loss: 0.8672 - yolo_layer_2_loss: 3.2205 - val_loss: 23.7897 - val_yolo_layer_1_loss: 6.6773 - val_yolo_layer_2_loss: 13.8246
#
# Epoch 00042: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 43/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 7.3391 - yolo_layer_1_loss: 0.8809 - yolo_layer_2_loss: 3.1797 - val_loss: 23.5961 - val_yolo_layer_1_loss: 6.6988 - val_yolo_layer_2_loss: 13.6280
#
# Epoch 00043: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 44/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 7.3563 - yolo_layer_1_loss: 0.8310 - yolo_layer_2_loss: 3.2649 - val_loss: 23.7504 - val_yolo_layer_1_loss: 6.6708 - val_yolo_layer_2_loss: 13.8280
#
# Epoch 00044: val_loss did not improve from 23.54578
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 45/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 7.3496 - yolo_layer_1_loss: 0.7616 - yolo_layer_2_loss: 3.3452 - val_loss: 23.8549 - val_yolo_layer_1_loss: 6.6432 - val_yolo_layer_2_loss: 13.9781
#
# Epoch 00045: val_loss did not improve from 23.54578
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 46/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 7.3453 - yolo_layer_1_loss: 0.8209 - yolo_layer_2_loss: 3.2996 - val_loss: 24.1109 - val_yolo_layer_1_loss: 6.9198 - val_yolo_layer_2_loss: 13.9750
#
# Epoch 00046: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 47/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 7.3253 - yolo_layer_1_loss: 0.8019 - yolo_layer_2_loss: 3.3161 - val_loss: 24.2042 - val_yolo_layer_1_loss: 6.8912 - val_yolo_layer_2_loss: 14.1145
#
# Epoch 00047: val_loss did not improve from 23.54578
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 48/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 7.1510 - yolo_layer_1_loss: 0.7593 - yolo_layer_2_loss: 3.2021 - val_loss: 23.9665 - val_yolo_layer_1_loss: 6.6374 - val_yolo_layer_2_loss: 14.1484
#
# Epoch 00048: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 49/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 7.1287 - yolo_layer_1_loss: 0.8793 - yolo_layer_2_loss: 3.0770 - val_loss: 23.6795 - val_yolo_layer_1_loss: 6.6176 - val_yolo_layer_2_loss: 13.8979
#
# Epoch 00049: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 50/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 7.1971 - yolo_layer_1_loss: 0.8200 - yolo_layer_2_loss: 3.2215 - val_loss: 24.0189 - val_yolo_layer_1_loss: 6.8440 - val_yolo_layer_2_loss: 14.0277
#
# Epoch 00050: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 51/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 7.0478 - yolo_layer_1_loss: 0.7392 - yolo_layer_2_loss: 3.1705 - val_loss: 23.8614 - val_yolo_layer_1_loss: 6.7786 - val_yolo_layer_2_loss: 13.9535
#
# Epoch 00051: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 52/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 7.0581 - yolo_layer_1_loss: 0.7492 - yolo_layer_2_loss: 3.1882 - val_loss: 23.8004 - val_yolo_layer_1_loss: 6.6518 - val_yolo_layer_2_loss: 14.0362
#
# Epoch 00052: val_loss did not improve from 23.54578
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 53/1000
# 750/750 [==============================] - 44s 58ms/step - loss: 6.9987 - yolo_layer_1_loss: 0.7286 - yolo_layer_2_loss: 3.1663 - val_loss: 23.9739 - val_yolo_layer_1_loss: 6.8799 - val_yolo_layer_2_loss: 13.9990
#
# Epoch 00053: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 54/1000
# 750/750 [==============================] - 45s 61ms/step - loss: 6.9578 - yolo_layer_1_loss: 0.8123 - yolo_layer_2_loss: 3.0588 - val_loss: 23.6285 - val_yolo_layer_1_loss: 6.6710 - val_yolo_layer_2_loss: 13.8789
#
# Epoch 00054: val_loss did not improve from 23.54578
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 55/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.9695 - yolo_layer_1_loss: 0.6564 - yolo_layer_2_loss: 3.2430 - val_loss: 23.8845 - val_yolo_layer_1_loss: 6.7550 - val_yolo_layer_2_loss: 14.0675
#
# Epoch 00055: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 56/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 6.9213 - yolo_layer_1_loss: 0.8104 - yolo_layer_2_loss: 3.0573 - val_loss: 23.8221 - val_yolo_layer_1_loss: 6.8462 - val_yolo_layer_2_loss: 13.9303
#
# Epoch 00056: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 57/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 6.7969 - yolo_layer_1_loss: 0.7478 - yolo_layer_2_loss: 3.0119 - val_loss: 23.7311 - val_yolo_layer_1_loss: 6.8201 - val_yolo_layer_2_loss: 13.8818
#
# Epoch 00057: val_loss did not improve from 23.54578
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 58/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 6.8642 - yolo_layer_1_loss: 0.8139 - yolo_layer_2_loss: 3.0294 - val_loss: 23.5117 - val_yolo_layer_1_loss: 6.5146 - val_yolo_layer_2_loss: 13.9842
#
# Epoch 00058: val_loss improved from 23.54578 to 23.51173, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep058-val_loss23.512-loss6.864.h5
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 59/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.7638 - yolo_layer_1_loss: 0.7117 - yolo_layer_2_loss: 3.0473 - val_loss: 23.7984 - val_yolo_layer_1_loss: 6.7649 - val_yolo_layer_2_loss: 14.0368
#
# Epoch 00059: val_loss did not improve from 23.51173
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 60/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 6.7450 - yolo_layer_1_loss: 0.7519 - yolo_layer_2_loss: 3.0044 - val_loss: 23.4600 - val_yolo_layer_1_loss: 6.6155 - val_yolo_layer_2_loss: 13.8637
#
# Epoch 00060: val_loss improved from 23.51173 to 23.46001, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep060-val_loss23.460-loss6.745.h5
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 61/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 6.6591 - yolo_layer_1_loss: 0.7368 - yolo_layer_2_loss: 2.9493 - val_loss: 23.4204 - val_yolo_layer_1_loss: 6.5920 - val_yolo_layer_2_loss: 13.8632
#
# Epoch 00061: val_loss improved from 23.46001 to 23.42041, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep061-val_loss23.420-loss6.659.h5
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 62/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 6.7211 - yolo_layer_1_loss: 0.8100 - yolo_layer_2_loss: 2.9536 - val_loss: 23.3308 - val_yolo_layer_1_loss: 6.5549 - val_yolo_layer_2_loss: 13.8260
#
# Epoch 00062: val_loss improved from 23.42041 to 23.33085, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep062-val_loss23.331-loss6.721.h5
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 63/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.7067 - yolo_layer_1_loss: 0.6594 - yolo_layer_2_loss: 3.1055 - val_loss: 23.5298 - val_yolo_layer_1_loss: 6.7472 - val_yolo_layer_2_loss: 13.8489
#
# Epoch 00063: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 64/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.6607 - yolo_layer_1_loss: 0.7374 - yolo_layer_2_loss: 2.9970 - val_loss: 23.6008 - val_yolo_layer_1_loss: 6.7647 - val_yolo_layer_2_loss: 13.9173
#
# Epoch 00064: val_loss did not improve from 23.33085
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 65/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.7227 - yolo_layer_1_loss: 0.7667 - yolo_layer_2_loss: 3.0447 - val_loss: 23.4444 - val_yolo_layer_1_loss: 6.5076 - val_yolo_layer_2_loss: 14.0332
#
# Epoch 00065: val_loss did not improve from 23.33085
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 66/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 6.5479 - yolo_layer_1_loss: 0.7986 - yolo_layer_2_loss: 2.8535 - val_loss: 23.4975 - val_yolo_layer_1_loss: 6.5604 - val_yolo_layer_2_loss: 14.0490
#
# Epoch 00066: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 67/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 6.5540 - yolo_layer_1_loss: 0.7368 - yolo_layer_2_loss: 2.9367 - val_loss: 23.5932 - val_yolo_layer_1_loss: 6.3912 - val_yolo_layer_2_loss: 14.3291
#
# Epoch 00067: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 68/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.5674 - yolo_layer_1_loss: 0.7004 - yolo_layer_2_loss: 3.0017 - val_loss: 23.5040 - val_yolo_layer_1_loss: 6.8537 - val_yolo_layer_2_loss: 13.7925
#
# Epoch 00068: val_loss did not improve from 23.33085
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 69/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 6.4392 - yolo_layer_1_loss: 0.8002 - yolo_layer_2_loss: 2.7888 - val_loss: 23.5298 - val_yolo_layer_1_loss: 6.6559 - val_yolo_layer_2_loss: 14.0315
#
# Epoch 00069: val_loss did not improve from 23.33085
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 70/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.3865 - yolo_layer_1_loss: 0.6830 - yolo_layer_2_loss: 2.8685 - val_loss: 23.8586 - val_yolo_layer_1_loss: 6.9171 - val_yolo_layer_2_loss: 14.1140
#
# Epoch 00070: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 71/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 6.3493 - yolo_layer_1_loss: 0.7022 - yolo_layer_2_loss: 2.8269 - val_loss: 23.5742 - val_yolo_layer_1_loss: 6.5901 - val_yolo_layer_2_loss: 14.1711
#
# Epoch 00071: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 72/1000
# 750/750 [==============================] - 46s 62ms/step - loss: 6.3420 - yolo_layer_1_loss: 0.6857 - yolo_layer_2_loss: 2.8507 - val_loss: 23.6832 - val_yolo_layer_1_loss: 6.7196 - val_yolo_layer_2_loss: 14.1655
#
# Epoch 00072: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 73/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 6.3609 - yolo_layer_1_loss: 0.6741 - yolo_layer_2_loss: 2.8959 - val_loss: 23.5412 - val_yolo_layer_1_loss: 6.7218 - val_yolo_layer_2_loss: 14.0358
#
# Epoch 00073: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 74/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.3753 - yolo_layer_1_loss: 0.6441 - yolo_layer_2_loss: 2.9547 - val_loss: 23.8950 - val_yolo_layer_1_loss: 6.8046 - val_yolo_layer_2_loss: 14.3205
#
# Epoch 00074: val_loss did not improve from 23.33085
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 75/1000
# 750/750 [==============================] - 47s 63ms/step - loss: 6.3092 - yolo_layer_1_loss: 0.7507 - yolo_layer_2_loss: 2.7960 - val_loss: 23.3798 - val_yolo_layer_1_loss: 6.5479 - val_yolo_layer_2_loss: 14.0767
#
# Epoch 00075: val_loss did not improve from 23.33085
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 76/1000
# 750/750 [==============================] - 47s 62ms/step - loss: 6.2428 - yolo_layer_1_loss: 0.7251 - yolo_layer_2_loss: 2.7698 - val_loss: 23.4732 - val_yolo_layer_1_loss: 6.5820 - val_yolo_layer_2_loss: 14.1501
#
# Epoch 00076: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 77/1000
# 750/750 [==============================] - 45s 60ms/step - loss: 6.2404 - yolo_layer_1_loss: 0.6589 - yolo_layer_2_loss: 2.8473 - val_loss: 23.8069 - val_yolo_layer_1_loss: 6.8031 - val_yolo_layer_2_loss: 14.2768
#
# Epoch 00077: val_loss did not improve from 23.33085
#
#
# 0 0.0001
# mAP: 0.0001
# mAP did not improve from 0.00034794711203897004.
# Epoch 78/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 6.2409 - yolo_layer_1_loss: 0.7276 - yolo_layer_2_loss: 2.7930 - val_loss: 23.4295 - val_yolo_layer_1_loss: 6.7037 - val_yolo_layer_2_loss: 14.0124
#
# Epoch 00078: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 79/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.2684 - yolo_layer_1_loss: 0.7160 - yolo_layer_2_loss: 2.8459 - val_loss: 23.3702 - val_yolo_layer_1_loss: 6.6878 - val_yolo_layer_2_loss: 13.9829
#
# Epoch 00079: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 80/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.2757 - yolo_layer_1_loss: 0.6710 - yolo_layer_2_loss: 2.9121 - val_loss: 23.5962 - val_yolo_layer_1_loss: 6.7548 - val_yolo_layer_2_loss: 14.1553
#
# Epoch 00080: val_loss did not improve from 23.33085
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 81/1000
# 750/750 [==============================] - 47s 62ms/step - loss: 6.1349 - yolo_layer_1_loss: 0.7849 - yolo_layer_2_loss: 2.6708 - val_loss: 22.9555 - val_yolo_layer_1_loss: 6.3788 - val_yolo_layer_2_loss: 13.9041
#
# Epoch 00081: val_loss improved from 23.33085 to 22.95555, saving model to chk/TSD_YOLOv3_Tiny_TinyV3_416x416_ep081-val_loss22.956-loss6.135.h5
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 82/1000
# 750/750 [==============================] - 46s 61ms/step - loss: 6.1625 - yolo_layer_1_loss: 0.6792 - yolo_layer_2_loss: 2.8174 - val_loss: 23.1062 - val_yolo_layer_1_loss: 6.5764 - val_yolo_layer_2_loss: 13.8705
#
# Epoch 00082: val_loss did not improve from 22.95555
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 83/1000
# 750/750 [==============================] - 44s 59ms/step - loss: 6.1722 - yolo_layer_1_loss: 0.6438 - yolo_layer_2_loss: 2.8756 - val_loss: 23.6127 - val_yolo_layer_1_loss: 6.7985 - val_yolo_layer_2_loss: 14.1680
#
# Epoch 00083: val_loss did not improve from 22.95555
#
#
# 0 0.0000
# mAP: 0.0000
# mAP did not improve from 0.00034794711203897004.
# Epoch 84/1000
#   1/750 [..............................] - ETA: 31s - loss: 6.1236 - yolo_layer_1_loss: 6.7727e-04 - yolo_layer_2_loss: 3.4767
